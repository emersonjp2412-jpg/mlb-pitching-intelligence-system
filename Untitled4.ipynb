# %%
import os
# !git clone https://github.com/emersonjp2412-jpg/mlb-pitching-intelligence-system.git
project_name = "mlb-pitching-intelligence-system"
if os.path.exists(project_name):
    os.chdir(project_name)
    print(f"Changed current working directory to '/content/{project_name}'")
else:
    print(f"Directory '{project_name}' not found.")
# Out:
# Cloning into 'mlb-pitching-intelligence-system'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# Changed current working directory to '/content/mlb-pitching-intelligence-system'
